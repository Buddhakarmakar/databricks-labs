# %%
# %sql

use catalog dbacademy;

use schema labuser11184542_1755240991;

# %%
# %sql
select current_schema();
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>current_schema()</th></tr></thead><tbody><tr><td>labuser11184542_1755240991</td></tr></tbody></table></div>

# %%
# %sql

drop table if exists my_user_table;
CREATE OR REPLACE TABLE my_user_table (
    ID INT,
    firstname STRING,
    age INT,
    created_date TIMESTAMP
);

-- Insert 5 rows into the table
INSERT INTO my_user_table (ID, firstname, age, created_date) VALUES
(1, 'Alice', 30, current_timestamp()),
(2, 'Bob', 25, current_timestamp()),
(3, 'Charlie', 35, current_timestamp()),
(4, 'David', 28, current_timestamp()),
(5, 'Eva', 22, current_timestamp());
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

# %%
# %sql
select * from my_user_table;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ID</th><th>firstname</th><th>age</th><th>created_date</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>30</td><td>2025-08-15T10:51:37.8027Z</td></tr><tr><td>2</td><td>Bob</td><td>25</td><td>2025-08-15T10:51:37.8027Z</td></tr><tr><td>3</td><td>Charlie</td><td>35</td><td>2025-08-15T10:51:37.8027Z</td></tr><tr><td>4</td><td>David</td><td>28</td><td>2025-08-15T10:51:37.8027Z</td></tr><tr><td>5</td><td>Eva</td><td>22</td><td>2025-08-15T10:51:37.8027Z</td></tr></tbody></table></div>
